# %%
# %run ../utils/utils

# %%
# %run ../config/config

# %% [markdown]
# #  CAMADA BRONZE

# %%
# %run ../ingestion/bronze

# %%
# %run ../ingestion/silver

# %%
# %run ../ingestion/gold

# %%
# %run ../ingestion/insights
