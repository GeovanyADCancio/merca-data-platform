# %%
  # %run ../utils/utils

# %%
 # %run ../config/config

# %%
# %run ../ingestion/silver/silver_clientes

# %%
# %run ../ingestion/silver/silver_enderecos

# %%
# %run ../ingestion/silver/silver_categorias

# %%
# %run ../ingestion/silver/silver_produtos

# %%
# %run ../ingestion/silver/silver_pedidos

# %%
# %run ../ingestion/silver/silver_itens_pedidos

# %%
# %run ../ingestion/silver/silver_rastreamento
