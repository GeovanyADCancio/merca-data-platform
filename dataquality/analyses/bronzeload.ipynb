# %%
# %run ../utils/utils

# %%
# %run ../config/config

# %%
# %run ../ingestion/bronze/bronze_categorias

# %%
# %run ../ingestion/bronze/bronze_clientes

# %%
# %run ../ingestion/bronze/bronze_enderecos

# %%
# %run ../ingestion/bronze/bronze_itens_pedidos

# %%
# %run ../ingestion/bronze/bronze_pedidos

# %%
# %run ../ingestion/bronze/bronze_produtos

# %%
# %run ../ingestion/bronze/bronze_rastreamento
