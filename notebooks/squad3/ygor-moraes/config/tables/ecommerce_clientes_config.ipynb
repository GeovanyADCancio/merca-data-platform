# %%
SOURCE_FILE = "ecommerce_clientes.csv"

TARGET_TABLE = "ecommerce_clientes"
TARGET_FULL_TABLE = f"{TARGET_SCHEMA}.{TARGET_TABLE}"

WRITE_MODE = "overwrite"

CSV_OPTIONS = {
    "header": "true",
    "inferSchema": "false",
}

EXPECTED_COLUMNS = [
    "id_cliente",
    "uuid_cliente",
    "nome",
    "sobrenome",
    "email",
    "senha_hash",
    "dt_cadastro",
    "dt_ultima_atualizacao",
]

METADATA_COLUMNS = [
    "dt_carga",
]

KEY_COLUMNS = ["id_cliente"]

VALIDATE_EXPECTED_COLUMNS = True
VALIDATE_KEY_COLUMNS = True

SOURCE_PATH = f"{RAW_BATCH_PATH}{SOURCE_FILE}"

# -----------------------------
# Configuração da camada Bronze
# -----------------------------

BRONZE_TABLE = "ecommerce_clientes"
BRONZE_PATH = f"{BRONZE_BASE_PATH}{BRONZE_TABLE}"

PARTITION_DATE_COLUMN = "dt_cadastro"

BRONZE_WRITE_MODE = "overwrite"
