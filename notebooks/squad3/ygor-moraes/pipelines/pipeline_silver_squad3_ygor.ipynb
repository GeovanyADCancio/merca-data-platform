# %%
# Executa notebooks Silver do pipeline Squad 3

notebooks_silver = [
    "../silver/02_silver_squad3_ecommerce_clientes",
    "../silver/02_silver_squad3_ecommerce_rastreamento_entregas",
    "../silver/02_silver_squad3_feriados",
    "../silver/02_silver_squad3_ibge_renda_uf"
]

for notebook in notebooks_silver:
    print(f"Iniciando execução: {notebook}")
    
    resultado = dbutils.notebook.run(
        notebook,
        timeout_seconds=0
    )
    
    print(f"Execução concluída: {notebook}")
    print(f"Resultado: {resultado}")
