# %%
# Executa notebooks Gold do pipeline Squad 3

notebooks_gold = [
    "../gold/03_gold_squad3_ecommerce_clientes_cadastros_mensal",
    "../gold/03_gold_squad3_ecommerce_clientes_ativos_cohort",
    "../gold/03_gold_squad3_ecommerce_clientes_ltv_cohort",
    "../gold/03_gold_squad3_ecommerce_clientes_distribuicao_estado",
    "../gold/03_gold_squad3_ecommerce_clientes_perfil_socioeconomico_uf",

    "../gold/03_gold_squad3_ecommerce_rastreamento_entregas_tempo_medio_mensal",
    "../gold/03_gold_squad3_ecommerce_rastreamento_entregas_sla_mensal",
    "../gold/03_gold_squad3_ecommerce_rastreamento_entregas_problemas_mensal",
    "../gold/03_gold_squad3_ecommerce_rastreamento_entregas_volume_estado_mom",
    "../gold/03_gold_squad3_ecommerce_rastreamento_entregas_feriados_sucesso"
]

for notebook in notebooks_gold:
    print(f"Iniciando execução: {notebook}")
    
    resultado = dbutils.notebook.run(
        notebook,
        timeout_seconds=0
    )
    
    print(f"Execução concluída: {notebook}")
    print(f"Resultado: {resultado}")
