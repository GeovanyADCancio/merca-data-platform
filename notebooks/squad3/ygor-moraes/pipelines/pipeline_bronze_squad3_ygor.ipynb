# %%
# Executa notebooks Bronze do pipeline Squad 3

notebooks_bronze = [
    "../bronze/01_bronze_squad3_ecommerce_clientes",
    "../bronze/01_bronze_squad3_ecommerce_rastreamento_entregas"
]

for notebook in notebooks_bronze:
    print(f"Iniciando execução: {notebook}")
    
    resultado = dbutils.notebook.run(
        notebook,
        timeout_seconds=0
    )
    
    print(f"Execução concluída: {notebook}")
    print(f"Resultado: {resultado}")
