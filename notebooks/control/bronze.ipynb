# %%
# %run /Workspace/Users/kalitamariano01@gmail.com/merca-data-platform/notebooks/utils/utils_feat_squad2_99_helpers

# %%
camada = "bronze"
tabela = "rastreamento"

arquivos_processados = ler_checkpoint(camada, tabela)

# depois que processar os arquivos novos:
arquivos_processados.update(novos_arquivos_processados)

salvar_checkpoint(camada, arquivos_processados, tabela)
