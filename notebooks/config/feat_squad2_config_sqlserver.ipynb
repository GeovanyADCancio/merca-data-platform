# %%
# Ler as variáveis de ambiente
from dotenv import load_dotenv
import os

load_dotenv()

# %%
# Create connection with Azure SQL Server
jdbc_hostname = os.getenv("JDBC_HOSTNAME")
jdbc_database = os.getenv("JDBC_DATABASE")
jdbc_username = os.getenv("JDBC_USERNAME")
jdbc_password = os.getenv("JDBC_PASSWORD")

# %%
# Criar a url de conexão
jdbc_url = (
    f"jdbc:sqlserver://{jdbc_hostname}:1433;"
    f"database={jdbc_database};"
    "encrypt=true;"
    "trustServerCertificate=false;"
    "hostNameInCertificate=*.database.windows.net;"
    "loginTimeout=30;"
)

# %%
# Criar a conexão com o Azure SQL Server
connection_properties = {
    "user": jdbc_username,
    "password": jdbc_password,
    "driver": "com.microsoft.sqlserver.jdbc.SQLServerDriver"
}

# %%
# Testar a conexão
query = "(SELECT 1 AS teste) AS tmp"

df_test = (
    spark.read
         .jdbc(
             url=jdbc_url,
             table=query,
             properties=connection_properties
         )
)

display(df_test)
